# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
eurusd = pd.read_csv('C:\\Users\\Smart\\Desktop\\PY\\eurusd.csv',index_col='Date')

# %%
eurusd.head()
# Out:
#                Open    Close      OC2      OPC2
# Date
# 01/01/2018  1.19985  1.19985      NaN       NaN
# 01/02/2018  1.20102  1.20583      NaN       NaN
# 01/03/2018  1.20581  1.20141  0.00598  0.498397
# 01/04/2018  1.20142  1.20680 -0.00442 -0.366546
# 01/05/2018  1.20679  1.20304  0.00539  0.448634

# %%
eurusd['Close'].plot(figsize=(15,18))

# %%
# values = []
# for i in range(1,201,1):
#    values.append(eurusd['Close'].rolling(i).mean()
#    values.mean()

# %%
values=[]
for i in range(51):
    values = eurusd['Close'].rolling(i).mean()
    values.mean()

# %%
values
# Out:
# 1.1810433254716988

# %%
eurusd['values']
# Out:
# Date
# 01/01/2018         NaN
# 01/02/2018         NaN
# 01/03/2018         NaN
# 01/04/2018         NaN
# 01/05/2018         NaN
# 01/08/2018         NaN
# 01/09/2018         NaN
# 01/10/2018         NaN
# 01/11/2018         NaN
# 01/12/2018         NaN
# 01/15/2018         NaN
# 01/16/2018         NaN
# 01/17/2018         NaN
# 01/18/2018         NaN
# 01/19/2018         NaN
# 01/22/2018         NaN
# 01/23/2018         NaN
# 01/24/2018         NaN
# 01/25/2018         NaN
# 01/26/2018         NaN
# 01/29/2018         NaN
# 01/30/2018         NaN
# 01/31/2018         NaN
# 02/01/2018         NaN
# 02/02/2018         NaN
# 02/05/2018         NaN
# 02/06/2018         NaN
# 02/07/2018         NaN
# 02/08/2018         NaN
# 02/09/2018         NaN
#                 ...
# 11/20/2018    1.150265
# 11/21/2018    1.149782
# 11/22/2018    1.149203
# 11/23/2018    1.148628
# 11/26/2018    1.147917
# 11/27/2018    1.147161
# 11/28/2018    1.146548
# 11/29/2018    1.145780
# ...

# %%
eurusd['ma50'] = eurusd['Close'].rolling(50).mean()

# %%
eurusd[['ma50','values']]
# Out:
#                 ma50    values
# Date
# 01/01/2018       NaN       NaN
# 01/02/2018       NaN       NaN
# 01/03/2018       NaN       NaN
# 01/04/2018       NaN       NaN
# 01/05/2018       NaN       NaN
# 01/08/2018       NaN       NaN
# 01/09/2018       NaN       NaN
# 01/10/2018       NaN       NaN
# 01/11/2018       NaN       NaN
# 01/12/2018       NaN       NaN
# 01/15/2018       NaN       NaN
# 01/16/2018       NaN       NaN
# 01/17/2018       NaN       NaN
# 01/18/2018       NaN       NaN
# 01/19/2018       NaN       NaN
# 01/22/2018       NaN       NaN
# 01/23/2018       NaN       NaN
# 01/24/2018       NaN       NaN
# 01/25/2018       NaN       NaN
# 01/26/2018       NaN       NaN
# 01/29/2018       NaN       NaN
# 01/30/2018       NaN       NaN
# 01/31/2018       NaN       NaN
# 02/01/2018       NaN       NaN
# 02/02/2018       NaN       NaN
# 02/05/2018       NaN       NaN
# 02/06/2018       NaN       NaN
# 02/07/2018       NaN       NaN
# 02/08/2018       NaN       NaN
# ...
